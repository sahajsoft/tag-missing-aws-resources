# %%
import boto3
import pandas as pd
import logging
import json
import warnings
import concurrent.futures

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')
logger = logging.getLogger()

# Suppress boto3 DeprecationWarning
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# /var/folders/81/j2n1pjkd4g7b5vf7tgnn2jyw0000gn/T/ipykernel_41759/2875187703.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def list_resources(region):
    logger.info(f"Listing resources in region {region}...")
    resourcegroupstaggingapi_client = boto3.client('resourcegroupstaggingapi', region_name=region)
    response = resourcegroupstaggingapi_client.get_resources()
    return response['ResourceTagMappingList']

# Get a list of all AWS regions
ec2_client = boto3.client('ec2')
regions = [region['RegionName'] for region in ec2_client.describe_regions()['Regions']]
# Out:
# INFO: Found credentials in shared credentials file: ~/.aws/credentials

# %%
with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    # Submit tasks for each region
    futures = [executor.submit(list_resources, region) for region in regions]

    # Wait for all tasks to complete and get the results
    all_resources = []
    for future in concurrent.futures.as_completed(futures):
        all_resources.extend(future.result())

# Create a DataFrame from the resource data
df = pd.DataFrame(all_resources)
# Out:
# INFO: Listing resources in region ap-south-1...
# INFO: Listing resources in region eu-north-1...
# INFO: Listing resources in region eu-west-3...
# INFO: Listing resources in region eu-west-2...
# INFO: Listing resources in region eu-west-1...
# INFO: Listing resources in region ap-northeast-3...
# INFO: Listing resources in region ap-northeast-2...
# INFO: Listing resources in region ap-northeast-1...
# INFO: Listing resources in region ca-central-1...
# INFO: Listing resources in region sa-east-1...
# INFO: Listing resources in region ap-southeast-1...
# INFO: Listing resources in region ap-southeast-2...
# INFO: Listing resources in region eu-central-1...
# INFO: Listing resources in region us-east-1...
# INFO: Listing resources in region us-east-2...
# INFO: Listing resources in region us-west-1...
# INFO: Listing resources in region us-west-2...

# %%
df
# Out:
#                                            ResourceARN  \
# 0    arn:aws:acm:ap-south-1:331061725593:certificat...
# 1    arn:aws:acm:ap-south-1:331061725593:certificat...
# 2    arn:aws:apigateway:ap-south-1::/apis/tsazuw5m8...
# 3    arn:aws:apigateway:ap-south-1::/apis/wtwybkii0...
# 4    arn:aws:apigateway:ap-south-1::/apis/nd63lcppv...
# ..                                                 ...
# 461  arn:aws:kms:ap-northeast-2:331061725593:key/7c...
# 462  arn:aws:logs:ap-northeast-2:331061725593:log-g...
# 463  arn:aws:cloudformation:ap-northeast-2:33106172...
# 464  arn:aws:ec2:ap-northeast-2:331061725593:intern...
# 465  arn:aws:ec2:ap-northeast-2:331061725593:natgat...
#
#                                                   Tags
# 0    [{'Key': 'Info', 'Value': 'For Autograder'}, {...
# 1    [{'Key': 'createdBy', 'Value': 'sadhak-team@sa...
# 2    [{'Key': 'ghr:environment', 'Value': 'sadhak-c...
# 3    [{'Key': 'ghr:environment', 'Value': 'gh-ci'},...
# 4    [{'Key': 'ghr:environment', 'Value': 'gh-ci'},...
# ..                                                 ...
# 461  [{'Key': 'createdBy', 'Value': 'mahesh'}, {'Ke...
# 462  [{'Key': 'UsedBy', 'Value': 'Sadhak'}, {'Key':...
# 463           [{'Key': 'displayName', 'Value': 'clr'}]
# 464  [{'Key': 'UsedBy', 'Value': 'Sadhak'}, {'Key':...
# 465  [{'Key': 'CreatedBy', 'Value': 'HummingBird'},...
#
# [466 rows x 2 columns]

# %%
from pandas import json_normalize

tags_df = pd.DataFrame(df['Tags'].apply(lambda tags: {tag['Key']: tag['Value'] for tag in tags}).tolist())
df = pd.concat([df['ResourceARN'], tags_df], axis=1)

# %%
df
# Out:
#                                            ResourceARN            Info  \
# 0    arn:aws:acm:ap-south-1:331061725593:certificat...  For Autograder
# 1    arn:aws:acm:ap-south-1:331061725593:certificat...             NaN
# 2    arn:aws:apigateway:ap-south-1::/apis/tsazuw5m8...             NaN
# 3    arn:aws:apigateway:ap-south-1::/apis/wtwybkii0...             NaN
# 4    arn:aws:apigateway:ap-south-1::/apis/nd63lcppv...             NaN
# ..                                                 ...             ...
# 461  arn:aws:kms:ap-northeast-2:331061725593:key/7c...             NaN
# 462  arn:aws:logs:ap-northeast-2:331061725593:log-g...             NaN
# 463  arn:aws:cloudformation:ap-northeast-2:33106172...             NaN
# 464  arn:aws:ec2:ap-northeast-2:331061725593:intern...             NaN
# 465  arn:aws:ec2:ap-northeast-2:331061725593:natgat...             NaN
#
#             Contact             createdBy      project ghr:environment  \
# 0    Kartikay/Naman                   NaN          NaN             NaN
# 1               NaN  sadhak-team@sahaj.ai       sadhak             NaN
# 2               NaN                   NaN          NaN       sadhak-ci
# 3               NaN                   NaN          NaN           gh-ci
# 4               NaN                   NaN          NaN           gh-ci
# ..              ...                   ...          ...             ...
# 461             NaN                mahesh  hummingbird             NaN
# 462             NaN                   NaN          NaN             NaN
# 463             NaN                   NaN          NaN             NaN
# 464             NaN                   NaN          NaN             NaN
# 465             NaN                   NaN          NaN             NaN
#
#             CreatedBy                       Purpose owner environment  ...  \
# 0                 NaN                           NaN   NaN         NaN  ...
# 1                 NaN                           NaN   NaN         NaN  ...
# 2    Dnyaneshwar Ware  Sadhak Github Actions Runner   NaN         NaN  ...
# 3    Dnyaneshwar Ware          Sadhak Github Runner   NaN         NaN  ...
# 4    Dnyaneshwar Ware          Sadhak Github Runner   NaN         NaN  ...
# ..                ...                           ...   ...         ...  ...
# 461               NaN                           NaN   NaN         NaN  ...
# 462               NaN                           NaN   NaN         NaN  ...
# 463               NaN                           NaN   NaN         NaN  ...
# 464               NaN                           NaN   NaN         NaN  ...
# 465       HummingBird                           NaN   NaN         NaN  ...
#
#     ingress.k8s.aws/resource elbv2.k8s.aws/cluster service.k8s.aws/stack  \
# 0                        NaN                   NaN                   NaN
# 1                        NaN                   NaN                   NaN
# 2                        NaN                   NaN                   NaN
# 3                        NaN                   NaN                   NaN
# 4                        NaN                   NaN                   NaN
# ..                       ...                   ...                   ...
# 461                      NaN                   NaN                   NaN
# 462                      NaN                   NaN                   NaN
# 463                      NaN                   NaN                   NaN
# 464                      NaN                   NaN                   NaN
# 465                      NaN                   NaN                   NaN
#
#     service.k8s.aws/resource kubernetes.io/cluster/cloud-enabled-8cn  \
# 0                        NaN                                     NaN
# 1                        NaN                                     NaN
# 2                        NaN                                     NaN
# 3                        NaN                                     NaN
# 4                        NaN                                     NaN
# ..                       ...                                     ...
# 461                      NaN                                     NaN
# 462                      NaN                                     NaN
# 463                      NaN                                     NaN
# 464                      NaN                                     NaN
# 465                      NaN                                     NaN
#
#     kubernetes.io/cluster/humming-bird-yov HummingBird  \
# 0                                      NaN         NaN
# 1                                      NaN         NaN
# 2                                      NaN         NaN
# 3                                      NaN         NaN
# 4                                      NaN         NaN
# ..                                     ...         ...
# 461                                    NaN         NaN
# 462                                    NaN         NaN
# 463                                    NaN         NaN
# 464                                    NaN         NaN
# 465                                    NaN         NaN
#
#     kubernetes.io/cluster/cloud-enabled-jra  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 461                                     NaN
# 462                                     NaN
# 463                                     NaN
# 464                                     NaN
# 465                                     NaN
#
#     kubernetes.io/cluster/humming-bird-cp-301  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 461                                       NaN
# 462                                       NaN
# 463                                       NaN
# 464                                       NaN
# 465                                       NaN
#
#     kubernetes.io/cluster/c-m-n9kc4b7x
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 461                                NaN
# 462                                NaN
# 463                                NaN
# 464                                NaN
# 465                                NaN
#
# [466 rows x 129 columns]

# %%
df.columns.unique()
# Out:
# Index(['ResourceARN', 'Info', 'Contact', 'createdBy', 'project',
#        'ghr:environment', 'CreatedBy', 'Purpose', 'owner', 'environment',
#        ...
#        'ingress.k8s.aws/resource', 'elbv2.k8s.aws/cluster',
#        'service.k8s.aws/stack', 'service.k8s.aws/resource',
#        'kubernetes.io/cluster/cloud-enabled-8cn',
#        'kubernetes.io/cluster/humming-bird-yov', 'HummingBird',
#        'kubernetes.io/cluster/cloud-enabled-jra',
#        'kubernetes.io/cluster/humming-bird-cp-301',
#        'kubernetes.io/cluster/c-m-n9kc4b7x'],
#       dtype='object', length=129)

# %%
# Define the list of column names to check
columns_to_match = ['Name', 'Owner', 'Project']
columns_to_match_lower = [col.lower() for col in columns_to_match]

# Get unique columns that case-insensitively match the list
matched_columns = [col for col in df.columns if col.lower() in columns_to_match_lower]
matched_columns
# Out:
# ['project', 'owner', 'Name', 'Owner', 'Project']

# %%
# Define the list of columns to check

# Check if any of the columns don't exist or are falsy
filter_mask = df.apply(lambda x: any(col not in x.index or pd.isnull(x[col]) for col in matched_columns), axis = 1)

# Filter the DataFrame
filtered_df = df[filter_mask]

filtered_df['NullValues'] = filtered_df.apply(lambda x: ', '.join(col for col in matched_columns if col not in x.index or pd.isnull(x[col]) or x[col] == ''), axis=1)

filtered_df
# Out:
#                                            ResourceARN            Info  \
# 0    arn:aws:acm:ap-south-1:331061725593:certificat...  For Autograder
# 1    arn:aws:acm:ap-south-1:331061725593:certificat...             NaN
# 2    arn:aws:apigateway:ap-south-1::/apis/tsazuw5m8...             NaN
# 3    arn:aws:apigateway:ap-south-1::/apis/wtwybkii0...             NaN
# 4    arn:aws:apigateway:ap-south-1::/apis/nd63lcppv...             NaN
# ..                                                 ...             ...
# 461  arn:aws:kms:ap-northeast-2:331061725593:key/7c...             NaN
# 462  arn:aws:logs:ap-northeast-2:331061725593:log-g...             NaN
# 463  arn:aws:cloudformation:ap-northeast-2:33106172...             NaN
# 464  arn:aws:ec2:ap-northeast-2:331061725593:intern...             NaN
# 465  arn:aws:ec2:ap-northeast-2:331061725593:natgat...             NaN
#
#             Contact             createdBy      project ghr:environment  \
# 0    Kartikay/Naman                   NaN          NaN             NaN
# 1               NaN  sadhak-team@sahaj.ai       sadhak             NaN
# 2               NaN                   NaN          NaN       sadhak-ci
# 3               NaN                   NaN          NaN           gh-ci
# 4               NaN                   NaN          NaN           gh-ci
# ..              ...                   ...          ...             ...
# 461             NaN                mahesh  hummingbird             NaN
# 462             NaN                   NaN          NaN             NaN
# 463             NaN                   NaN          NaN             NaN
# 464             NaN                   NaN          NaN             NaN
# 465             NaN                   NaN          NaN             NaN
#
#             CreatedBy                       Purpose owner environment  ...  \
# 0                 NaN                           NaN   NaN         NaN  ...
# 1                 NaN                           NaN   NaN         NaN  ...
# 2    Dnyaneshwar Ware  Sadhak Github Actions Runner   NaN         NaN  ...
# 3    Dnyaneshwar Ware          Sadhak Github Runner   NaN         NaN  ...
# 4    Dnyaneshwar Ware          Sadhak Github Runner   NaN         NaN  ...
# ..                ...                           ...   ...         ...  ...
# 461               NaN                           NaN   NaN         NaN  ...
# 462               NaN                           NaN   NaN         NaN  ...
# 463               NaN                           NaN   NaN         NaN  ...
# 464               NaN                           NaN   NaN         NaN  ...
# 465       HummingBird                           NaN   NaN         NaN  ...
#
#     elbv2.k8s.aws/cluster service.k8s.aws/stack service.k8s.aws/resource  \
# 0                     NaN                   NaN                      NaN
# 1                     NaN                   NaN                      NaN
# 2                     NaN                   NaN                      NaN
# 3                     NaN                   NaN                      NaN
# 4                     NaN                   NaN                      NaN
# ..                    ...                   ...                      ...
# 461                   NaN                   NaN                      NaN
# 462                   NaN                   NaN                      NaN
# 463                   NaN                   NaN                      NaN
# 464                   NaN                   NaN                      NaN
# 465                   NaN                   NaN                      NaN
#
#     kubernetes.io/cluster/cloud-enabled-8cn  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 461                                     NaN
# 462                                     NaN
# 463                                     NaN
# 464                                     NaN
# 465                                     NaN
#
#     kubernetes.io/cluster/humming-bird-yov HummingBird  \
# 0                                      NaN         NaN
# 1                                      NaN         NaN
# 2                                      NaN         NaN
# 3                                      NaN         NaN
# 4                                      NaN         NaN
# ..                                     ...         ...
# 461                                    NaN         NaN
# 462                                    NaN         NaN
# 463                                    NaN         NaN
# 464                                    NaN         NaN
# 465                                    NaN         NaN
#
#     kubernetes.io/cluster/cloud-enabled-jra  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 461                                     NaN
# 462                                     NaN
# 463                                     NaN
# 464                                     NaN
# 465                                     NaN
#
#     kubernetes.io/cluster/humming-bird-cp-301  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 461                                       NaN
# 462                                       NaN
# 463                                       NaN
# 464                                       NaN
# 465                                       NaN
#
#     kubernetes.io/cluster/c-m-n9kc4b7x                            NullValues
# 0                                  NaN  project, owner, Name, Owner, Project
# 1                                  NaN           owner, Name, Owner, Project
# 2                                  NaN  project, owner, Name, Owner, Project
# 3                                  NaN  project, owner, Name, Owner, Project
# 4                                  NaN  project, owner, Name, Owner, Project
# ..                                 ...                                   ...
# 461                                NaN           owner, Name, Owner, Project
# 462                                NaN        project, owner, Owner, Project
# 463                                NaN  project, owner, Name, Owner, Project
# 464                                NaN        project, owner, Owner, Project
# 465                                NaN        project, owner, Owner, Project
#
# [466 rows x 130 columns]

# %%
filtered_df[['ResourceARN', 'NullValues']].to_csv('missing-tags.csv', index=False)
